# %%
"""
The original decoration ID "WebLightJobPosting-23" provides only basic job information. 
To get more comprehensive job details, modify the decorationId in the get_job function located in linkedin_api/linkedin.py as follows:

params = {
    "decorationId": "com.linkedin.voyager.deco.jobs.web.shared.WebFullJobPosting-65",
}

"""
# Out:
# '\nThe original decoration ID "WebLightJobPosting-23" provides only basic job information. \nTo get more comprehensive job details, modify the decorationId in the get_job function located in linkedin_api/linkedin.py as follows:\n\nparams = {\n    "decorationId": "com.linkedin.voyager.deco.jobs.web.shared.WebFullJobPosting-65",\n}\n\n'

# %%
from linkedin_api import Linkedin
import time
import json
import logging
from pprint import pprint

# workplace typr mapping function

def get_workplace_type(workplace_types):
   # Map workplace type URN to readable format
   workplace_mapping = {
       'urn:li:fs_workplaceType:1': 'On-site',
       'urn:li:fs_workplaceType:2': 'Remote',
       'urn:li:fs_workplaceType:3': 'Hybrid'
   }
   
   # Return workplace type if exists, otherwise "N/A"
   return workplace_mapping.get(workplace_types[0], "N/A") if workplace_types else "N/A"


# Setup logging for errors and debugging
logging.basicConfig(filename='job_scraper_errors.log', level=logging.ERROR)

# Authenticate using your LinkedIn credentials
email = ""  # Replace with your LinkedIn email
password = ""  # Replace with your LinkedIn password
api = Linkedin(email, password)

# Test authentication
try:
    profile = api.get_profile()
    print(f"Authenticated as: {profile['firstName']} {profile['lastName']}")
except Exception as e:
    print(f"Authentication failed: {e}")
    exit()

# Define job search parameters
search_params = {
    'keywords': 'data engineer',
    'location_name': 'Sydney',
    'count': 30,  # Results per page
    'limit': 3,  # Max results (adjust as needed)
    
    
}

# Initialize storage for job data
all_jobs = []

# Fetch jobs
try:
    print("\nSearching for jobs...")
    jobs = api.search_jobs(**search_params)
    print(f"Found {len(jobs)} jobs.")

    # Fetch job details
    for job in jobs:
        try:
            # Extract job ID
            job_id = job.get('id') or job.get('entityUrn', '').split(':')[-1]
            if not job_id:
                print("Job ID not found, skipping...")
                continue

            # Fetch job details
            job_details = api.get_job(job_id)
            job_skills = api.get_job_skills(job_id)

            # Debugging: Print available keys
            print(f"\nJob ID: {job_id}")
            print("-" * 30)
            print(f"Job keys: {list(job.keys())}")
            print(f"Job details keys: {list(job_details.keys())}")
            print(f"Job Skills Data for Job ID {job_id}:")
            pprint(job_skills)

            # Extract relevant fields

            # Company extraction
            company = (
                job.get('companyName') or
                job_details.get('companyName') or
                job_details.get('companyDetails', {}).get('companyName') or
                job_details.get('companyDetails', {}).get('company', {}).get('name') or
                job_skills.get('company', {}).get('name') or
                "N/A"
            )

            # Location extraction
            location = (
                job.get('formattedLocation') or
                job_details.get('formattedLocation') or
                job_details.get('locationDescription') or
                job_details.get('location', {}).get('city') or
                job_details.get('location', {}).get('country') or
                "N/A"
            )


            # Employment Status extraction
            employment_type = job_details.get('formattedEmploymentStatus') or "N/A"

            # Expeirence Level extraction
            seniority_level = job_details.get('formattedExperienceLevel') or "N/A"

            # Industries extraction
            industries = job_details.get('formattedIndustries') or "N/A"

            # Job Functions extraction
            job_functions = job_details.get('formattedJobFunctions') or "N/A"

            # Applies extraction
            applies = job_details.get('applies') or "N/A"

            # Work Place Type extraction
            workplace_type = get_workplace_type(job_details.get('workplaceTypes', []))

            # If reposted?
            reposted_job = job.get('repostedJob', "N/A")

            # Extract skills
            if 'skillMatchStatuses' in job_skills:
                skills = [
                    skill_status.get('skill', {}).get('name', 'Unknown Skill')
                    for skill_status in job_skills.get('skillMatchStatuses', [])
                ]
            else:
                skills = ["Skills not listed"]

            # Extract posting time
            listed_at = job.get('listedAt') or job_details.get('listedAt')
            if listed_at:
                # Convert LinkedIn timestamp to human-readable format
                post_time = time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(listed_at / 1000))
            else:
                post_time = "N/A"

            
            # Extract expiring time
            expire_at = job.get('expireAt') or job_details.get('expireAt')
            if expire_at:
                # Convert LinkedIn timestamp to human-readable format
                expire_time = time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(expire_at / 1000))
            else:
                expire_time = "N/A"


            

            # Store job data
            job_info = {
                "title": job.get('title', "N/A"),
                "company": company,
                "location": location,
                "empoyment type":employment_type,
                "seniority level":seniority_level,
                "industries":industries,
                "Job Functions":job_functions,
                "applies":applies,
                "workplace_type":workplace_type,
                "description": job_details.get('description', {}).get('text', "N/A"),
                "skills": skills,
                "job_url": f"https://www.linkedin.com/jobs/view/{job_id}",
                "if reposted": reposted_job,    
                "posted_time": post_time,
                "expire_time": expire_time
            }

            print(f"Fetched job: {job_info['title']} at {job_info['company']}")
            all_jobs.append(job_info)

            # Throttle requests
            time.sleep(2)

        except Exception as detail_error:
            logging.error(f"Error fetching details for job ID {job_id}: {detail_error}")
            print(f"Error fetching details for job ID {job_id}: {detail_error}")

except Exception as search_error:
    logging.error(f"Error searching for jobs: {search_error}")
    print(f"Error searching for jobs: {search_error}")

# Save jobs to a JSON file
output_file = "linkedin_jobs.json"
with open(output_file, 'w') as f:
    json.dump(all_jobs, f, indent=4)

print(f"\nJob data saved to {output_file}.")
# Out:
# Authenticated as: Jeff B.
#
# Searching for jobs...
# Found 3 jobs.
#
# Job ID: 4088696105
# ------------------------------
# Job keys: ['trackingUrn', 'repostedJob', 'title', '$recipeTypes', 'posterId', '$type', 'contentSource', 'entityUrn']
# Job details keys: ['standardizedTitle', 'companyDetails', 'employmentStatusResolutionResult', 'employmentStatus', 'ownerViewEnabled', 'hiringDashboardViewEnabled', 'talentHubJob', 'formattedLocation', 'jobPostingUrl', 'applies', '$recipeType', 'applyingInfo', 'workplaceTypesResolutionResults', 'dashEntityUrn', 'eligibleForLearningCourseRecsUpsell', 'eligibleForSharingProfileWithPoster', 'originalListedAt', 'entityUrn', 'workRemoteAllowed', 'applyMethod', 'benefitsDataSource', 'savingInfo', 'formattedJobFunctions', 'dashJobPostingCardUrn', 'locationVisibility', 'expireAt', 'claimableByViewer', 'formattedIndustries', 'industries', 'salaryInsights', 'country', 'jobPosterEntitlements', 'standardizedTitleResolutionResult', 'locationUrn', 'jobApplicationLimitReached', 'new', 'applicantTrackingSystem', 'workplaceTypes', 'contentSource', 'formattedExperienceLevel', 'jobFunctions', 'benefits', 'encryptedPricingParams', 'jobState', 'trackingUrn', 'description', 'formattedEmploymentStatus', 'title', 'thirdPartySourced', 'views', 'eligibleForReferrals', 'allJobHiringTeamMembersInjectionResult', 'listedAt', 'jobPostingId', 'allowedToEdit']
# Job Skills Data for Job ID 4088696105:
# {'$recipeType': 'com.linkedin.voyager.dash.deco.assessments.FullJobSkillMatchInsight',
#  'company': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1326778634',
#              'entityUrn': 'urn:li:fsd_company:102635657',
#              'logo': {'vectorImage': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorImageOnlyRootUrl',
#                                       'artifacts': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#                                                      'expiresAt': 1741219200000,
#                                                      'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1715878361635/refonte_learning_logo?e=1741219200&v=beta&t=9Hvv5P2FDw5URCdOilhd2PsnDqPxQmhJrBJv_-lP500',
#                                                      'height': 200,
#                                                      'width': 200},
#                                                     {'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#                                                      'expiresAt': 1741219200000,
#                                                      'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1715878361636/refonte_learning_logo?e=1741219200&v=beta&t=Lw0xrYdS72CKJ6OglrucMJIx1BMVckpROpxXBmz1AHY',
#                                                      'height': 100,
#                                                      'width': 100},
#                                                     {'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#                                                      'expiresAt': 1741219200000,
#                                                      'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1715878361636/refonte_learning_logo?e=1741219200&v=beta&t=3XYdRqNFiQe_QV9VggzKm7p__ImlKjjjx_bfB_9XQ94',
#                                                      'height': 400,
#                                                      'width': 400}],
#                                       'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQEnzYA12lGBOg/company-logo_'}},
#              'name': 'Refonte Learning'},
#  'companyUrn': 'urn:li:fsd_company:102635657',
#  'detailsContent': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                     'accessibilityText': 'Learn more about how your skills are '
#                                          'matched',
#                     'attributesV2': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                       'detailDataUnion': {'hyperlink': 'https://www.linkedin.com/help/linkedin/answer/a793433?lang=en'},
#                                       'length': 10,
#                                       'start': 73},
#                                      {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                       'detailDataUnion': {'style': 'BOLD'},
#                                       'length': 10,
#                                       'start': 73}],
#                     'text': '0 skills found on your profile match the skills '
#                             'associated with the job. Learn more',
#                     'textDirection': 'USER_LOCALE'},
#  'detailsHeader': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                    'attributesV2': [],
#                    'text': 'Skills added by the job poster',
#                    'textDirection': 'USER_LOCALE'},
#  'detailsTitle': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                   'attributesV2': [],
#                   'text': 'Qualification details',
#                   'textDirection': 'USER_LOCALE'},
#  'entityUrn': 'urn:li:fsd_jobSkillMatchInsight:4088696105',
#  'insightSummary': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.ux.baseInsightViewModel',
#                     'image': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageViewModel',
#                               'attributes': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageAttribute',
#                                               'detailDataUnion': {'systemImage': 'SYS_ICN_CHECKLIST_MEDIUM'}}]},
#                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                              'attributesV2': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                                'detailDataUnion': {'hyperlink': '#HYM'},
#                                                'length': 50,
#                                                'start': 0}],
#                              'text': 'Skills: Software Implementation, '
#                                      'React.js, +9 more',
#                              'textDirection': 'USER_LOCALE'}},
#  'jobSkillsVersion': 'TARGETING_SEGMENT_P4P',
#  'shouldShowJobSkillsFeedback': True,
#  'skillLimitInsight': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.ux.baseInsightViewModel',
#                        'image': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageViewModel',
#                                  'attributes': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageAttribute',
#                                                  'detailDataUnion': {'systemImage': 'SYS_ICN_SIGNAL_NOTICE_SMALL'},
#                                                  'tintColor': 'ICON'}]},
#                        'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                 'attributesV2': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                                   'detailDataUnion': {'hyperlink': 'https://www.linkedin.com/in/ron-kyler-2a558633a/details/skills?profileUrn=urn%3Ali%3Afsd_profile%3AACoAAFUojh0B9vOoXK_UYiNh1wn-c5yUkV-ltw0'},
#                                                   'length': 11,
#                                                   'start': 48},
#                                                  {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                                   'detailDataUnion': {'style': 'BOLD'},
#                                                   'length': 11,
#                                                   'start': 48}],
#                                 'text': 'You can manage all your skills on '
#                                         'your profile. Edit skills',
#                                 'textDirection': 'USER_LOCALE'}},
#  'skillMatchStatuses': [{'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Agile Methodologies as a skill. '
#                                               'If you have this skill, you can '
#                                               'add it to your profile.',
#                          'localizedSkillDisplayName': 'Agile Methodologies',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:1608',
#                                    'name': 'Agile Methodologies'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A1608',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Agile '
#                                                                                   'Methodologies '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:1608'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Industry standards as a skill. '
#                                               'If you have this skill, you can '
#                                               'add it to your profile.',
#                          'localizedSkillDisplayName': 'Industry standards',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:59285',
#                                    'name': 'Industry standards'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A59285',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Industry '
#                                                                                   'standards '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:59285'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show Java '
#                                               'as a skill. If you have this '
#                                               'skill, you can add it to your '
#                                               'profile.',
#                          'localizedSkillDisplayName': 'Java',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:147',
#                                    'name': 'Java'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A147',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Java '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:147'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'JavaScript as a skill. If you '
#                                               'have this skill, you can add it '
#                                               'to your profile.',
#                          'localizedSkillDisplayName': 'JavaScript',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:218',
#                                    'name': 'JavaScript'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A218',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'JavaScript '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:218'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Object-Oriented Programming '
#                                               '(OOP) as a skill. If you have '
#                                               'this skill, you can add it to '
#                                               'your profile.',
#                          'localizedSkillDisplayName': 'Object-Oriented '
#                                                       'Programming (OOP)',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:1328',
#                                    'name': 'Object-Oriented Programming (OOP)'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A1328',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Object-Oriented '
#                                                                                   'Programming '
#                                                                                   '(OOP) '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:1328'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Programming as a skill. If you '
#                                               'have this skill, you can add it '
#                                               'to your profile.',
#                          'localizedSkillDisplayName': 'Programming',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:698',
#                                    'name': 'Programming'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A698',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Programming '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:698'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Python (Programming Language) '
#                                               'as a skill. If you have this '
#                                               'skill, you can add it to your '
#                                               'profile.',
#                          'localizedSkillDisplayName': 'Python (Programming '
#                                                       'Language)',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:1346',
#                                    'name': 'Python (Programming Language)'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A1346',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Python '
#                                                                                   '(Programming '
#                                                                                   'Language) '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:1346'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'React.js as a skill. If you '
#                                               'have this skill, you can add it '
#                                               'to your profile.',
#                          'localizedSkillDisplayName': 'React.js',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:55007',
#                                    'name': 'React.js'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A55007',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'React.js '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:55007'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Software Configuration '
#                                               'Management as a skill. If you '
#                                               'have this skill, you can add it '
#                                               'to your profile.',
#                          'localizedSkillDisplayName': 'Software Configuration '
#                                                       'Management',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:2611',
#                                    'name': 'Software Configuration Management'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A2611',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Software '
#                                                                                   'Configuration '
#                                                                                   'Management '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:2611'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Software Implementation as a '
#                                               'skill. If you have this skill, '
#                                               'you can add it to your profile.',
#                          'localizedSkillDisplayName': 'Software Implementation',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:2374',
#                                    'name': 'Software Implementation'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A2374',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Software '
#                                                                                   'Implementation '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:2374'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Version Control as a skill. If '
#                                               'you have this skill, you can '
#                                               'add it to your profile.',
#                          'localizedSkillDisplayName': 'Version Control',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:18470',
#                                    'name': 'Version Control'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A18470',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Version '
#                                                                                   'Control '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:18470'}],
#  'trackingReferenceId': '¯\x1dD\ro¬@³\x9d\x99\x9dI1(|\x05'}
# Fetched job: Junior Software Engineer Trainee - Software Development Internship Program at Refonte Learning
#
# Job ID: 4086305348
# ------------------------------
# Job keys: ['trackingUrn', 'repostedJob', 'title', '$recipeTypes', 'posterId', '$type', 'contentSource', 'entityUrn']
# Job details keys: ['standardizedTitle', 'companyDetails', 'employmentStatusResolutionResult', 'employmentStatus', 'ownerViewEnabled', 'hiringDashboardViewEnabled', 'talentHubJob', 'formattedLocation', 'companyDescription', 'jobPostingUrl', 'applies', '$recipeType', 'applyingInfo', 'workplaceTypesResolutionResults', 'dashEntityUrn', 'eligibleForLearningCourseRecsUpsell', 'eligibleForSharingProfileWithPoster', 'originalListedAt', 'entityUrn', 'workRemoteAllowed', 'applyMethod', 'benefitsDataSource', 'savingInfo', 'formattedJobFunctions', 'dashJobPostingCardUrn', 'locationVisibility', 'expireAt', 'claimableByViewer', 'formattedIndustries', 'industries', 'salaryInsights', 'country', 'jobPosterEntitlements', 'standardizedTitleResolutionResult', 'locationUrn', 'jobApplicationLimitReached', 'new', 'workplaceTypes', 'contentSource', 'formattedExperienceLevel', 'jobFunctions', 'benefits', 'encryptedPricingParams', 'jobState', 'trackingUrn', 'description', 'formattedEmploymentStatus', 'title', 'thirdPartySourced', 'views', 'eligibleForReferrals', 'allJobHiringTeamMembersInjectionResult', 'listedAt', 'jobPostingId', 'allowedToEdit', 'sourceDomain']
# Job Skills Data for Job ID 4086305348:
# {'$recipeType': 'com.linkedin.voyager.dash.deco.assessments.FullJobSkillMatchInsight',
#  'company': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1326778634',
#              'entityUrn': 'urn:li:fsd_company:60870',
#              'logo': {'vectorImage': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorImageOnlyRootUrl',
#                                       'artifacts': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#                                                      'expiresAt': 1741219200000,
#                                                      'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1725898995592/riot_games_logo?e=1741219200&v=beta&t=XhekNlCEZEoZ5aoApENTn2vQo12YGVangEOtHJhAc3A',
#                                                      'height': 200,
#                                                      'width': 200},
#                                                     {'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#                                                      'expiresAt': 1741219200000,
#                                                      'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1725898995592/riot_games_logo?e=1741219200&v=beta&t=wNbITPju2I35q0YSE_RFOHJ2qozRf7l88T7FJq0TTb0',
#                                                      'height': 100,
#                                                      'width': 100},
#                                                     {'$recipeType': 'com.linkedin.voyager.dash.deco.common.VectorArtifact',
#                                                      'expiresAt': 1741219200000,
#                                                      'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1725898995592/riot_games_logo?e=1741219200&v=beta&t=kkgLQaMqWQAFeumWLETRH_mc1Famf5EEjH8C3sbUxDI',
#                                                      'height': 400,
#                                                      'width': 400}],
#                                       'rootUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGJCu2U_L9CNQ/company-logo_'}},
#              'name': 'Riot Games'},
#  'companyUrn': 'urn:li:fsd_company:60870',
#  'detailsContent': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                     'accessibilityText': 'Learn more about how your skills are '
#                                          'matched',
#                     'attributesV2': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                       'detailDataUnion': {'hyperlink': 'https://www.linkedin.com/help/linkedin/answer/a793433?lang=en'},
#                                       'length': 10,
#                                       'start': 73},
#                                      {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                       'detailDataUnion': {'style': 'BOLD'},
#                                       'length': 10,
#                                       'start': 73}],
#                     'text': '0 skills found on your profile match the skills '
#                             'associated with the job. Learn more',
#                     'textDirection': 'USER_LOCALE'},
#  'detailsHeader': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                    'attributesV2': [],
#                    'text': 'Skills associated with the job',
#                    'textDirection': 'USER_LOCALE'},
#  'detailsTitle': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                   'attributesV2': [],
#                   'text': 'Qualification details',
#                   'textDirection': 'USER_LOCALE'},
#  'entityUrn': 'urn:li:fsd_jobSkillMatchInsight:4086305348',
#  'insightSummary': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.ux.baseInsightViewModel',
#                     'image': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageViewModel',
#                               'attributes': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageAttribute',
#                                               'detailDataUnion': {'systemImage': 'SYS_ICN_CHECKLIST_MEDIUM'}}]},
#                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                              'attributesV2': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                                'detailDataUnion': {'hyperlink': '#HYM'},
#                                                'length': 51,
#                                                'start': 0}],
#                              'text': 'Skills: Computer Science, Game '
#                                      'Development, +8 more',
#                              'textDirection': 'USER_LOCALE'}},
#  'jobSkillsVersion': 'WATERLOO_STANDARDIZED_EXP2',
#  'shouldShowJobSkillsFeedback': True,
#  'skillLimitInsight': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.ux.baseInsightViewModel',
#                        'image': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageViewModel',
#                                  'attributes': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageAttribute',
#                                                  'detailDataUnion': {'systemImage': 'SYS_ICN_SIGNAL_NOTICE_SMALL'},
#                                                  'tintColor': 'ICON'}]},
#                        'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                 'attributesV2': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                                   'detailDataUnion': {'hyperlink': 'https://www.linkedin.com/in/ron-kyler-2a558633a/details/skills?profileUrn=urn%3Ali%3Afsd_profile%3AACoAAFUojh0B9vOoXK_UYiNh1wn-c5yUkV-ltw0'},
#                                                   'length': 11,
#                                                   'start': 48},
#                                                  {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2',
#                                                   'detailDataUnion': {'style': 'BOLD'},
#                                                   'length': 11,
#                                                   'start': 48}],
#                                 'text': 'You can manage all your skills on '
#                                         'your profile. Edit skills',
#                                 'textDirection': 'USER_LOCALE'}},
#  'skillMatchStatuses': [{'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Back-End Web Development as a '
#                                               'skill. If you have this skill, '
#                                               'you can add it to your profile.',
#                          'localizedSkillDisplayName': 'Back-End Web '
#                                                       'Development',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:42068',
#                                    'name': 'Back-End Web Development'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A42068',
#                                                     'controlName': 'add_skill',
# ...
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Information '
#                                                                                   'Technology '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:4725'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show Pen '
#                                               'as a skill. If you have this '
#                                               'skill, you can add it to your '
#                                               'profile.',
#                          'localizedSkillDisplayName': 'Pen',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:4767',
#                                    'name': 'Pen'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A4767',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Pen '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:4767'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Security Awareness as a skill. '
#                                               'If you have this skill, you can '
#                                               'add it to your profile.',
#                          'localizedSkillDisplayName': 'Security Awareness',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:5350',
#                                    'name': 'Security Awareness'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A5350',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Security '
#                                                                                   'Awareness '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:5350'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Security Information and Event '
#                                               'Management (SIEM) as a skill. '
#                                               'If you have this skill, you can '
#                                               'add it to your profile.',
#                          'localizedSkillDisplayName': 'Security Information '
#                                                       'and Event Management '
#                                                       '(SIEM)',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:9164',
#                                    'name': 'Security Information and Event '
#                                            'Management (SIEM)'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A9164',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Security '
#                                                                                   'Information '
#                                                                                   'and '
#                                                                                   'Event '
#                                                                                   'Management '
#                                                                                   '(SIEM) '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:9164'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Stakeholder Engagement as a '
#                                               'skill. If you have this skill, '
#                                               'you can add it to your profile.',
#                          'localizedSkillDisplayName': 'Stakeholder Engagement',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:5052',
#                                    'name': 'Stakeholder Engagement'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A5052',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Stakeholder '
#                                                                                   'Engagement '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:5052'},
#                         {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon2132280934',
#                          'accessibilityText': 'Your profile does not show '
#                                               'Vulnerability Assessment as a '
#                                               'skill. If you have this skill, '
#                                               'you can add it to your profile.',
#                          'localizedSkillDisplayName': 'Vulnerability '
#                                                       'Assessment',
#                          'skill': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon503562015',
#                                    'entityUrn': 'urn:li:fsd_standardizedSkill:3278',
#                                    'name': 'Vulnerability Assessment'},
#                          'skillAssessmentVerified': False,
#                          'skillMatchActionButton': {'$recipeType': 'com.linkedin.deco.recipe.anonymous.Anon1090596515',
#                                                     'actionUrl': 'https://www.linkedin.com/in/ron-kyler-2a558633a/skill-add-edit?profileFormEntryPoint=JOB_DETAIL_STRONG_SKILL_MATCH&skillUrn=urn%3Ali%3Afsd_standardizedSkill%3A3278',
#                                                     'controlName': 'add_skill',
#                                                     'icon': 'SYS_ICN_ADD_SMALL',
#                                                     'text': {'$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#                                                              'accessibilityText': 'Add '
#                                                                                   'Vulnerability '
#                                                                                   'Assessment '
#                                                                                   'as '
#                                                                                   'a '
#                                                                                   'skill '
#                                                                                   'to '
#                                                                                   'your '
#                                                                                   'profile',
#                                                              'accessibilityTextAttributesV2': [],
#                                                              'attributesV2': [],
#                                                              'text': 'Add',
#                                                              'textDirection': 'USER_LOCALE'}},
#                          'skillOnProfile': False,
#                          'skillUrn': 'urn:li:fsd_standardizedSkill:3278'}],
#  'trackingReferenceId': '2?7g-çHE\x8bÄ\n¸u2q\xad'}
# Fetched job: Cyber Security and Systems Specialist at Public Sector People
#
# Job data saved to linkedin_jobs.json.
